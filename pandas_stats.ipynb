# %%
# Pandas Descriptive Statistics with Grouped Analysis and Comments

# Import necessary libraries
import pandas as pd  # For handling tabular data
import os  # For checking file paths
import time  # For measuring performance
import matplotlib.pyplot as plt  # For plotting
import seaborn as sns  # For statistical visualization

# Ensure plots are displayed inside the notebook
# %matplotlib inline

# Define dataset filenames
DATASETS = [
    "2024_fb_ads_president_scored_anon.csv",
    "2024_fb_posts_president_scored_anon.csv",
    "2024_tw_posts_president_scored_anon.csv"
]

# Filter datasets to include only those that exist
available_datasets = [f for f in DATASETS if os.path.exists(f)]

# Function to analyze each dataset
def analyze_dataset(csv_file):
    print(f"\n{'='*60}\nAnalyzing File: {csv_file}\n{'='*60}")  # Header for current file
    start_time = time.time()  # Record start time

    df = pd.read_csv(csv_file)  # Read the dataset into a DataFrame

    if df.empty:
        print("No data in file.")  # Exit if DataFrame is empty
        return

    print("\n--- Data Overview ---")
    print(f"Shape: {df.shape}")  # Print the number of rows and columns
    print(f"Columns: {list(df.columns)}")  # Print column names

    print("\n--- Descriptive Statistics for First 5 Columns ---")
    for col in df.columns[:5]:  # Limit output to first 5 columns
        if pd.api.types.is_numeric_dtype(df[col]):  # Check if column is numeric
            print(f"\nColumn: {col} (Numeric)")
            print(df[col].describe())  # Show descriptive stats
        else:
            print(f"\nColumn: {col} (Categorical)")
            print(df[col].value_counts().head(5))  # Show top 5 values

    if 'page_id' in df.columns:
        print("\n--- Grouped by 'page_id' (First 3 Groups Only) ---")
        grouped = df.groupby('page_id')  # Group by 'page_id'
        for name, group in list(grouped)[0:3]:  # Limit to 3 groups
            print(f"\nGroup: page_id = {name}")
            print(group.describe(include='all'))  # Show group stats

    if 'ad_id' in df.columns and 'page_id' in df.columns:
        print("\n--- Grouped by 'page_id' and 'ad_id' (First 3 Groups Only) ---")
        grouped = df.groupby(['page_id', 'ad_id'])  # Group by both keys
        for name, group in list(grouped)[0:3]:  # Limit to 3 groups
            print(f"\nGroup: page_id = {name[0]}, ad_id = {name[1]}")
            print(group.describe(include='all'))  # Show group stats

    print(f"\nFinished in {time.time() - start_time:.2f} seconds")  # Print time taken

# Run analysis for each dataset
for dataset in available_datasets:
    analyze_dataset(dataset)  # Execute function for each file
# Out:
# ============================================================
# Analyzing File: 2024_fb_ads_president_scored_anon.csv
# ============================================================
#
# --- Data Overview ---
# Shape: (246745, 41)
# Columns: ['page_id', 'ad_id', 'ad_creation_time', 'bylines', 'currency', 'delivery_by_region', 'demographic_distribution', 'estimated_audience_size', 'estimated_impressions', 'estimated_spend', 'publisher_platforms', 'illuminating_scored_message', 'illuminating_mentions', 'scam_illuminating', 'election_integrity_Truth_illuminating', 'advocacy_msg_type_illuminating', 'issue_msg_type_illuminating', 'attack_msg_type_illuminating', 'image_msg_type_illuminating', 'cta_msg_type_illuminating', 'engagement_cta_subtype_illuminating', 'fundraising_cta_subtype_illuminating', 'voting_cta_subtype_illuminating', 'covid_topic_illuminating', 'economy_topic_illuminating', 'education_topic_illuminating', 'environment_topic_illuminating', 'foreign_policy_topic_illuminating', 'governance_topic_illuminating', 'health_topic_illuminating', 'immigration_topic_illuminating', 'lgbtq_issues_topic_illuminating', 'military_topic_illuminating', 'race_and_ethnicity_topic_illuminating', 'safety_topic_illuminating', 'social_and_cultural_topic_illuminating', 'technology_and_privacy_topic_illuminating', 'womens_issue_topic_illuminating', 'incivility_illuminating', 'freefair_illuminating', 'fraud_illuminating']
#
# --- Descriptive Statistics for First 5 Columns ---
#
# Column: page_id (Categorical)
# page_id
# 4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d    55503
# e3342051b60393770363ffc02946a0f76bc3e4155190d1f05fb0277b34bf6480    23988
# 4ade404186269ec62d2dd7d9e0ed5f93a5f32c057516879d627ea9fbd628ef9b    14822
# 330b2f35ded2161e63fbb2b5c5bdae05bff274ff31f990c275d28ce408671ce0    10461
# ec8ac6dc1cddc49972de2c31b62343fe3979729ec437c3b8d6ffa8915ab1401d     9851
# Name: count, dtype: int64
#
# Column: ad_id (Categorical)
# ad_id
# 808105264f12fee56bafffa5f10d7e408b0d3d1a12ae96e07406ef785bbe5a05    1
# 0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc    1
# 86229868e6bde3661724fe02da93504bb4fb5da8c2550d7b7cf193c687e89fa6    1
# 07b5aefc27e872e971f793e49aac38496fa62e484f3928e2b6a2b6e3e08cac8d    1
# c62978153c04116d88ead49379916855f2cb58bf788631f26f3f1fcb2962ad48    1
# Name: count, dtype: int64
#
# Column: ad_creation_time (Categorical)
# ad_creation_time
# 2024-10-27    8619
# 2024-10-28    7356
# 2024-10-26    6414
# 2024-10-23    5021
# 2024-10-25    4769
# Name: count, dtype: int64
#
# Column: bylines (Categorical)
# bylines
# HARRIS FOR PRESIDENT                        49788
# HARRIS VICTORY FUND                         32612
# BIDEN VICTORY FUND                          15539
# DONALD J. TRUMP FOR PRESIDENT 2024, INC.    15112
# Trump National Committee JFC                 7279
# Name: count, dtype: int64
#
# Column: currency (Categorical)
# currency
# USD    246599
# INR        63
# GBP        17
# EUR        11
# EGP         8
# Name: count, dtype: int64
#
# --- Grouped by 'page_id' (First 3 Groups Only) ---
#
# Group: page_id = 0005687f4ac876c135dda2bd5aa60962eced3356228ef01c21c514d263a11128
#                                                   page_id  \
# count                                                   2
# unique                                                  1
# top     0005687f4ac876c135dda2bd5aa60962eced3356228ef0...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     ad_id ad_creation_time  \
# count                                                   2                2
# unique                                                  2                2
# top     5ae5f50e059148a06b00ef785636346997d35ee843d290...       2024-10-28
# freq                                                    1                1
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                               bylines currency  \
# count                               2        2
# unique                              1        1
# top     David Blount for State Senate      USD
# freq                                2        2
# mean                              NaN      NaN
# std                               NaN      NaN
# min                               NaN      NaN
# 25%                               NaN      NaN
# 50%                               NaN      NaN
# 75%                               NaN      NaN
# max                               NaN      NaN
#
#                                        delivery_by_region  \
# count                                                   2
# unique                                                  2
# top     {'Alabama': {'spend': 0, 'impressions': 26}, '...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  demographic_distribution  \
# count                                                   2
# unique                                                  2
# top     {'female_18-24': {'spend': 0, 'impressions': 3...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         estimated_audience_size  estimated_impressions  estimated_spend  ...  \
# count                  2.000000               2.000000              2.0  ...
# unique                      NaN                    NaN              NaN  ...
# top                         NaN                    NaN              NaN  ...
# freq                        NaN                    NaN              NaN  ...
# mean                5250.000000            3999.000000             49.0  ...
# std                 3181.980515            2121.320344              0.0  ...
# min                 3000.000000            2499.000000             49.0  ...
# 25%                 4125.000000            3249.000000             49.0  ...
# 50%                 5250.000000            3999.000000             49.0  ...
# 75%                 6375.000000            4749.000000             49.0  ...
# max                 7500.000000            5499.000000             49.0  ...
#
#        lgbtq_issues_topic_illuminating military_topic_illuminating  \
# count                              2.0                         2.0
# unique                             NaN                         NaN
# top                                NaN                         NaN
# freq                               NaN                         NaN
# mean                               0.0                         0.0
# std                                0.0                         0.0
# min                                0.0                         0.0
# 25%                                0.0                         0.0
# 50%                                0.0                         0.0
# 75%                                0.0                         0.0
# max                                0.0                         0.0
#
#        race_and_ethnicity_topic_illuminating  safety_topic_illuminating  \
# count                                    2.0                        2.0
# unique                                   NaN                        NaN
# top                                      NaN                        NaN
# freq                                     NaN                        NaN
# mean                                     0.0                        0.0
# std                                      0.0                        0.0
# min                                      0.0                        0.0
# 25%                                      0.0                        0.0
# 50%                                      0.0                        0.0
# 75%                                      0.0                        0.0
# max                                      0.0                        0.0
#
#         social_and_cultural_topic_illuminating  \
# count                                      2.0
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                       0.0
# std                                        0.0
# min                                        0.0
# 25%                                        0.0
# 50%                                        0.0
# 75%                                        0.0
# max                                        0.0
#
#         technology_and_privacy_topic_illuminating  \
# count                                         2.0
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                          0.0
# std                                           0.0
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                               2.0                      2.0
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# freq                                NaN                      NaN
# mean                                0.0                      0.0
# std                                 0.0                      0.0
# min                                 0.0                      0.0
# 25%                                 0.0                      0.0
# 50%                                 0.0                      0.0
# 75%                                 0.0                      0.0
# max                                 0.0                      0.0
#
#         freefair_illuminating  fraud_illuminating
# count                     2.0                 2.0
# unique                    NaN                 NaN
# top                       NaN                 NaN
# freq                      NaN                 NaN
# mean                      0.0                 0.0
# std                       0.0                 0.0
# min                       0.0                 0.0
# 25%                       0.0                 0.0
# 50%                       0.0                 0.0
# 75%                       0.0                 0.0
# max                       0.0                 0.0
#
# [11 rows x 41 columns]
#
# Group: page_id = 00157b7e28846e0510e1d265c5ea72fea289d9a3e31a91bb3ed242d8b17f4cd8
#                                                   page_id  \
# count                                                   3
# unique                                                  1
# top     00157b7e28846e0510e1d265c5ea72fea289d9a3e31a91...
# freq                                                    3
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     ad_id ad_creation_time  \
# count                                                   3                3
# unique                                                  3                3
# top     715ec14d254bf4e5b576e257e96f77967ef5c27604238e...       2024-07-29
# freq                                                    1                1
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                    bylines currency  \
# count                    3        3
# unique                   1        1
# top     Teran for Congress      USD
# freq                     3        3
# mean                   NaN      NaN
# std                    NaN      NaN
# min                    NaN      NaN
# 25%                    NaN      NaN
# 50%                    NaN      NaN
# 75%                    NaN      NaN
# max                    NaN      NaN
#
#                                        delivery_by_region  \
# count                                                   3
# unique                                                  3
# top     {'Arizona': {'spend': 1248, 'impressions': 274...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  demographic_distribution  \
# count                                                   3
# unique                                                  3
# top     {'unknown_18-24': {'spend': 0, 'impressions': ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         estimated_audience_size  estimated_impressions  estimated_spend  ...  \
# count                  3.000000               3.000000         3.000000  ...
# unique                      NaN                    NaN              NaN  ...
# top                         NaN                    NaN              NaN  ...
# freq                        NaN                    NaN              NaN  ...
# mean               12683.333333           32999.000000      1415.666667  ...
# std                15394.019401           29635.283025      1258.305739  ...
# min                  550.000000            6499.000000       249.000000  ...
# 25%                 4025.000000           16999.000000       749.000000  ...
# 50%                 7500.000000           27499.000000      1249.000000  ...
# 75%                18750.000000           46249.000000      1999.000000  ...
# max                30000.000000           64999.000000      2749.000000  ...
#
#        lgbtq_issues_topic_illuminating military_topic_illuminating  \
# count                              3.0                         3.0
# unique                             NaN                         NaN
# top                                NaN                         NaN
# freq                               NaN                         NaN
# mean                               0.0                         0.0
# std                                0.0                         0.0
# min                                0.0                         0.0
# 25%                                0.0                         0.0
# 50%                                0.0                         0.0
# 75%                                0.0                         0.0
# max                                0.0                         0.0
#
#        race_and_ethnicity_topic_illuminating  safety_topic_illuminating  \
# count                                    3.0                        3.0
# unique                                   NaN                        NaN
# top                                      NaN                        NaN
# freq                                     NaN                        NaN
# mean                                     0.0                        0.0
# std                                      0.0                        0.0
# min                                      0.0                        0.0
# 25%                                      0.0                        0.0
# 50%                                      0.0                        0.0
# 75%                                      0.0                        0.0
# max                                      0.0                        0.0
#
#         social_and_cultural_topic_illuminating  \
# count                                      3.0
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                       1.0
# std                                        0.0
# min                                        1.0
# 25%                                        1.0
# 50%                                        1.0
# 75%                                        1.0
# max                                        1.0
#
#         technology_and_privacy_topic_illuminating  \
# count                                         3.0
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                          0.0
# std                                           0.0
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                               3.0                      3.0
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# freq                                NaN                      NaN
# mean                                0.0                      0.0
# std                                 0.0                      0.0
# min                                 0.0                      0.0
# 25%                                 0.0                      0.0
# 50%                                 0.0                      0.0
# 75%                                 0.0                      0.0
# max                                 0.0                      0.0
#
#         freefair_illuminating  fraud_illuminating
# count                     3.0                 3.0
# unique                    NaN                 NaN
# top                       NaN                 NaN
# freq                      NaN                 NaN
# mean                      0.0                 0.0
# std                       0.0                 0.0
# min                       0.0                 0.0
# 25%                       0.0                 0.0
# 50%                       0.0                 0.0
# 75%                       0.0                 0.0
# max                       0.0                 0.0
#
# [11 rows x 41 columns]
#
# Group: page_id = 002415d34a27e69e6b9c0a2d1b0b8b99aacddf88c766ce1e8b897f69cbd3c928
#                                                   page_id  \
# count                                                   1
# unique                                                  1
# top     002415d34a27e69e6b9c0a2d1b0b8b99aacddf88c766ce...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     ad_id ad_creation_time  \
# count                                                   1                1
# unique                                                  1                1
# top     6001578eecf31f7e5ca33146ecede00c7b10d26a824028...       2024-03-10
# freq                                                    1                1
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                            bylines currency  \
# count                            1        1
# unique                           1        1
# top     Dr. Rick Tsai for congress      USD
# freq                             1        1
# mean                           NaN      NaN
# std                            NaN      NaN
# min                            NaN      NaN
# 25%                            NaN      NaN
# 50%                            NaN      NaN
# 75%                            NaN      NaN
# max                            NaN      NaN
#
#                                        delivery_by_region  \
# count                                                   1
# unique                                                  1
# top     {'Ohio': {'spend': 48, 'impressions': 1469}, '...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  demographic_distribution  \
# count                                                   1
# unique                                                  1
# top     {'unknown_45-54': {'spend': 0, 'impressions': ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         estimated_audience_size  estimated_impressions  estimated_spend  ...  \
# count                       1.0                    1.0              1.0  ...
# unique                      NaN                    NaN              NaN  ...
# top                         NaN                    NaN              NaN  ...
# freq                        NaN                    NaN              NaN  ...
# mean                   300000.0                 1499.0             49.0  ...
# std                         NaN                    NaN              NaN  ...
# min                    300000.0                 1499.0             49.0  ...
# 25%                    300000.0                 1499.0             49.0  ...
# 50%                    300000.0                 1499.0             49.0  ...
# 75%                    300000.0                 1499.0             49.0  ...
# max                    300000.0                 1499.0             49.0  ...
#
#        lgbtq_issues_topic_illuminating military_topic_illuminating  \
# count                              1.0                         1.0
# unique                             NaN                         NaN
# top                                NaN                         NaN
# freq                               NaN                         NaN
# mean                               0.0                         0.0
# std                                NaN                         NaN
# min                                0.0                         0.0
# 25%                                0.0                         0.0
# 50%                                0.0                         0.0
# 75%                                0.0                         0.0
# max                                0.0                         0.0
#
#        race_and_ethnicity_topic_illuminating  safety_topic_illuminating  \
# count                                    1.0                        1.0
# unique                                   NaN                        NaN
# top                                      NaN                        NaN
# freq                                     NaN                        NaN
# mean                                     0.0                        0.0
# std                                      NaN                        NaN
# min                                      0.0                        0.0
# 25%                                      0.0                        0.0
# 50%                                      0.0                        0.0
# 75%                                      0.0                        0.0
# max                                      0.0                        0.0
#
#         social_and_cultural_topic_illuminating  \
# count                                      1.0
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                       0.0
# std                                        NaN
# min                                        0.0
# 25%                                        0.0
# 50%                                        0.0
# 75%                                        0.0
# max                                        0.0
#
#         technology_and_privacy_topic_illuminating  \
# count                                         1.0
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                          0.0
# std                                           NaN
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                               1.0                      1.0
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# freq                                NaN                      NaN
# mean                                0.0                      0.0
# std                                 NaN                      NaN
# min                                 0.0                      0.0
# 25%                                 0.0                      0.0
# 50%                                 0.0                      0.0
# 75%                                 0.0                      0.0
# max                                 0.0                      0.0
#
#         freefair_illuminating  fraud_illuminating
# count                     1.0                 1.0
# unique                    NaN                 NaN
# top                       NaN                 NaN
# freq                      NaN                 NaN
# mean                      0.0                 0.0
# std                       NaN                 NaN
# min                       0.0                 0.0
# 25%                       0.0                 0.0
# 50%                       0.0                 0.0
# 75%                       0.0                 0.0
# max                       0.0                 0.0
#
# [11 rows x 41 columns]
#
# --- Grouped by 'page_id' and 'ad_id' (First 3 Groups Only) ---
#
# Group: page_id = 0005687f4ac876c135dda2bd5aa60962eced3356228ef01c21c514d263a11128, ad_id = 10913e6cae50d9aafe81b85c23f4ad11e24bde5d4f24643c14734a19a2733e5e
#                                                   page_id  \
# count                                                   1
# unique                                                  1
# top     0005687f4ac876c135dda2bd5aa60962eced3356228ef0...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     ad_id ad_creation_time  \
# count                                                   1                1
# unique                                                  1                1
# top     10913e6cae50d9aafe81b85c23f4ad11e24bde5d4f2464...       2024-08-23
# freq                                                    1                1
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                               bylines currency  \
# count                               1        1
# unique                              1        1
# top     David Blount for State Senate      USD
# freq                                1        1
# mean                              NaN      NaN
# std                               NaN      NaN
# min                               NaN      NaN
# 25%                               NaN      NaN
# 50%                               NaN      NaN
# 75%                               NaN      NaN
# max                               NaN      NaN
#
#                                        delivery_by_region  \
# count                                                   1
# unique                                                  1
# top     {'Massachusetts': {'spend': 0, 'impressions': ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  demographic_distribution  \
# count                                                   1
# unique                                                  1
# top     {'unknown_65+': {'spend': 0, 'impressions': 7}...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         estimated_audience_size  estimated_impressions  estimated_spend  ...  \
# count                       1.0                    1.0              1.0  ...
# unique                      NaN                    NaN              NaN  ...
# top                         NaN                    NaN              NaN  ...
# freq                        NaN                    NaN              NaN  ...
# mean                     7500.0                 5499.0             49.0  ...
# std                         NaN                    NaN              NaN  ...
# min                      7500.0                 5499.0             49.0  ...
# 25%                      7500.0                 5499.0             49.0  ...
# 50%                      7500.0                 5499.0             49.0  ...
# 75%                      7500.0                 5499.0             49.0  ...
# max                      7500.0                 5499.0             49.0  ...
#
#        lgbtq_issues_topic_illuminating military_topic_illuminating  \
# count                              1.0                         1.0
# unique                             NaN                         NaN
# top                                NaN                         NaN
# freq                               NaN                         NaN
# mean                               0.0                         0.0
# std                                NaN                         NaN
# min                                0.0                         0.0
# 25%                                0.0                         0.0
# 50%                                0.0                         0.0
# 75%                                0.0                         0.0
# max                                0.0                         0.0
#
#        race_and_ethnicity_topic_illuminating  safety_topic_illuminating  \
# count                                    1.0                        1.0
# unique                                   NaN                        NaN
# top                                      NaN                        NaN
# freq                                     NaN                        NaN
# mean                                     0.0                        0.0
# std                                      NaN                        NaN
# min                                      0.0                        0.0
# 25%                                      0.0                        0.0
# 50%                                      0.0                        0.0
# 75%                                      0.0                        0.0
# max                                      0.0                        0.0
#
#         social_and_cultural_topic_illuminating  \
# count                                      1.0
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                       0.0
# std                                        NaN
# min                                        0.0
# 25%                                        0.0
# 50%                                        0.0
# 75%                                        0.0
# max                                        0.0
#
#         technology_and_privacy_topic_illuminating  \
# count                                         1.0
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                          0.0
# std                                           NaN
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                               1.0                      1.0
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# freq                                NaN                      NaN
# mean                                0.0                      0.0
# std                                 NaN                      NaN
# min                                 0.0                      0.0
# 25%                                 0.0                      0.0
# 50%                                 0.0                      0.0
# 75%                                 0.0                      0.0
# max                                 0.0                      0.0
#
#         freefair_illuminating  fraud_illuminating
# count                     1.0                 1.0
# unique                    NaN                 NaN
# top                       NaN                 NaN
# freq                      NaN                 NaN
# mean                      0.0                 0.0
# std                       NaN                 NaN
# min                       0.0                 0.0
# 25%                       0.0                 0.0
# 50%                       0.0                 0.0
# 75%                       0.0                 0.0
# max                       0.0                 0.0
#
# [11 rows x 41 columns]
#
# Group: page_id = 0005687f4ac876c135dda2bd5aa60962eced3356228ef01c21c514d263a11128, ad_id = 5ae5f50e059148a06b00ef785636346997d35ee843d2900fe795e60bc39a535f
#                                                   page_id  \
# count                                                   1
# unique                                                  1
# top     0005687f4ac876c135dda2bd5aa60962eced3356228ef0...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     ad_id ad_creation_time  \
# count                                                   1                1
# unique                                                  1                1
# top     5ae5f50e059148a06b00ef785636346997d35ee843d290...       2024-10-28
# freq                                                    1                1
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                               bylines currency  \
# count                               1        1
# unique                              1        1
# top     David Blount for State Senate      USD
# freq                                1        1
# mean                              NaN      NaN
# std                               NaN      NaN
# min                               NaN      NaN
# 25%                               NaN      NaN
# 50%                               NaN      NaN
# 75%                               NaN      NaN
# max                               NaN      NaN
#
#                                        delivery_by_region  \
# count                                                   1
# unique                                                  1
# top     {'Alabama': {'spend': 0, 'impressions': 26}, '...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  demographic_distribution  \
# count                                                   1
# unique                                                  1
# top     {'female_18-24': {'spend': 0, 'impressions': 3...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         estimated_audience_size  estimated_impressions  estimated_spend  ...  \
# count                       1.0                    1.0              1.0  ...
# unique                      NaN                    NaN              NaN  ...
# top                         NaN                    NaN              NaN  ...
# freq                        NaN                    NaN              NaN  ...
# mean                     3000.0                 2499.0             49.0  ...
# std                         NaN                    NaN              NaN  ...
# min                      3000.0                 2499.0             49.0  ...
# 25%                      3000.0                 2499.0             49.0  ...
# 50%                      3000.0                 2499.0             49.0  ...
# 75%                      3000.0                 2499.0             49.0  ...
# max                      3000.0                 2499.0             49.0  ...
#
#        lgbtq_issues_topic_illuminating military_topic_illuminating  \
# count                              1.0                         1.0
# unique                             NaN                         NaN
# top                                NaN                         NaN
# freq                               NaN                         NaN
# mean                               0.0                         0.0
# std                                NaN                         NaN
# min                                0.0                         0.0
# 25%                                0.0                         0.0
# 50%                                0.0                         0.0
# 75%                                0.0                         0.0
# max                                0.0                         0.0
#
#        race_and_ethnicity_topic_illuminating  safety_topic_illuminating  \
# count                                    1.0                        1.0
# unique                                   NaN                        NaN
# top                                      NaN                        NaN
# freq                                     NaN                        NaN
# mean                                     0.0                        0.0
# std                                      NaN                        NaN
# min                                      0.0                        0.0
# 25%                                      0.0                        0.0
# 50%                                      0.0                        0.0
# 75%                                      0.0                        0.0
# max                                      0.0                        0.0
#
#         social_and_cultural_topic_illuminating  \
# count                                      1.0
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                       0.0
# std                                        NaN
# min                                        0.0
# 25%                                        0.0
# 50%                                        0.0
# 75%                                        0.0
# max                                        0.0
#
#         technology_and_privacy_topic_illuminating  \
# count                                         1.0
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                          0.0
# std                                           NaN
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                               1.0                      1.0
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# ...
#
#         freefair_illuminating  fraud_illuminating
# count                     1.0                 1.0
# unique                    NaN                 NaN
# top                       NaN                 NaN
# freq                      NaN                 NaN
# mean                      0.0                 0.0
# std                       NaN                 NaN
# min                       0.0                 0.0
# 25%                       0.0                 0.0
# 50%                       0.0                 0.0
# 75%                       0.0                 0.0
# max                       0.0                 0.0
#
# [11 rows x 41 columns]
#
# Group: page_id = 00157b7e28846e0510e1d265c5ea72fea289d9a3e31a91bb3ed242d8b17f4cd8, ad_id = 715ec14d254bf4e5b576e257e96f77967ef5c27604238eb4eac34d2f8467a10c
#                                                   page_id  \
# count                                                   1
# unique                                                  1
# top     00157b7e28846e0510e1d265c5ea72fea289d9a3e31a91...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     ad_id ad_creation_time  \
# count                                                   1                1
# unique                                                  1                1
# top     715ec14d254bf4e5b576e257e96f77967ef5c27604238e...       2024-07-29
# freq                                                    1                1
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                    bylines currency  \
# count                    1        1
# unique                   1        1
# top     Teran for Congress      USD
# freq                     1        1
# mean                   NaN      NaN
# std                    NaN      NaN
# min                    NaN      NaN
# 25%                    NaN      NaN
# 50%                    NaN      NaN
# 75%                    NaN      NaN
# max                    NaN      NaN
#
#                                        delivery_by_region  \
# count                                                   1
# unique                                                  1
# top     {'Arizona': {'spend': 1248, 'impressions': 274...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  demographic_distribution  \
# count                                                   1
# unique                                                  1
# top     {'unknown_18-24': {'spend': 0, 'impressions': ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         estimated_audience_size  estimated_impressions  estimated_spend  ...  \
# count                       1.0                    1.0              1.0  ...
# unique                      NaN                    NaN              NaN  ...
# top                         NaN                    NaN              NaN  ...
# freq                        NaN                    NaN              NaN  ...
# mean                    30000.0                27499.0           1249.0  ...
# std                         NaN                    NaN              NaN  ...
# min                     30000.0                27499.0           1249.0  ...
# 25%                     30000.0                27499.0           1249.0  ...
# 50%                     30000.0                27499.0           1249.0  ...
# 75%                     30000.0                27499.0           1249.0  ...
# max                     30000.0                27499.0           1249.0  ...
#
#        lgbtq_issues_topic_illuminating military_topic_illuminating  \
# count                              1.0                         1.0
# unique                             NaN                         NaN
# top                                NaN                         NaN
# freq                               NaN                         NaN
# mean                               0.0                         0.0
# std                                NaN                         NaN
# min                                0.0                         0.0
# 25%                                0.0                         0.0
# 50%                                0.0                         0.0
# 75%                                0.0                         0.0
# max                                0.0                         0.0
#
#        race_and_ethnicity_topic_illuminating  safety_topic_illuminating  \
# count                                    1.0                        1.0
# unique                                   NaN                        NaN
# top                                      NaN                        NaN
# freq                                     NaN                        NaN
# mean                                     0.0                        0.0
# std                                      NaN                        NaN
# min                                      0.0                        0.0
# 25%                                      0.0                        0.0
# 50%                                      0.0                        0.0
# 75%                                      0.0                        0.0
# max                                      0.0                        0.0
#
#         social_and_cultural_topic_illuminating  \
# count                                      1.0
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                       1.0
# std                                        NaN
# min                                        1.0
# 25%                                        1.0
# 50%                                        1.0
# 75%                                        1.0
# max                                        1.0
#
#         technology_and_privacy_topic_illuminating  \
# count                                         1.0
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                          0.0
# std                                           NaN
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                               1.0                      1.0
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# freq                                NaN                      NaN
# mean                                0.0                      0.0
# std                                 NaN                      NaN
# min                                 0.0                      0.0
# 25%                                 0.0                      0.0
# 50%                                 0.0                      0.0
# 75%                                 0.0                      0.0
# max                                 0.0                      0.0
#
#         freefair_illuminating  fraud_illuminating
# count                     1.0                 1.0
# unique                    NaN                 NaN
# top                       NaN                 NaN
# freq                      NaN                 NaN
# mean                      0.0                 0.0
# std                       NaN                 NaN
# min                       0.0                 0.0
# 25%                       0.0                 0.0
# 50%                       0.0                 0.0
# 75%                       0.0                 0.0
# max                       0.0                 0.0
#
# [11 rows x 41 columns]
#
# Finished in 29.70 seconds
#
# ============================================================
# Analyzing File: 2024_fb_posts_president_scored_anon.csv
# ============================================================
#
# --- Data Overview ---
# Shape: (19009, 56)
# Columns: ['Facebook_Id', 'post_id', 'Page Category', 'Page Admin Top Country', 'Post Created', 'Post Created Date', 'Post Created Time', 'Type', 'Total Interactions', 'Likes', 'Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 'Angry', 'Care', 'Video Share Status', 'Is Video Owner?', 'Post Views', 'Total Views', 'Total Views For All Crossposts', 'Video Length', 'Sponsor Id', 'Sponsor Name', 'Sponsor Category', 'Overperforming Score', 'illuminating_scored_messageelection_integrity_Truth_illuminating', 'advocacy_msg_type_illuminating', 'issue_msg_type_illuminating', 'attack_msg_type_illuminating', 'image_msg_type_illuminating', 'cta_msg_type_illuminating', 'engagement_cta_subtype_illuminating', 'fundraising_cta_subtype_illuminating', 'voting_cta_subtype_illuminating', 'covid_topic_illuminating', 'economy_topic_illuminating', 'education_topic_illuminating', 'environment_topic_illuminating', 'foreign_policy_topic_illuminating', 'governance_topic_illuminating', 'health_topic_illuminating', 'immigration_topic_illuminating', 'lgbtq_issues_topic_illuminating', 'military_topic_illuminating', 'race_and_ethnicity_topic_illuminating', 'safety_topic_illuminating', 'social_and_cultural_topic_illuminating', 'technology_and_privacy_topic_illuminating', 'womens_issue_topic_illuminating', 'incivility_illuminating', 'scam_illuminating', 'freefair_illuminating', 'fraud_illuminating']
#
# --- Descriptive Statistics for First 5 Columns ---
#
# Column: Facebook_Id (Categorical)
# Facebook_Id
# 32fc18da91029ff09bf74fe9887eace6b5d2145809d583f696e344530508b064    9013
# bfe51c6ac2cab17ba5c85883e76f61398031ed57e4cf62d19fd483548ebb904b    1431
# ac24f31c4d4b3d5555065fa9558bdca4ab4b5e1379922875ae9e6e32f1d46d25    1231
# 7f5731ac8e6959576e781064b5fa76e059200cdfc3f4e0d7b68bc98792d2cf5b    1158
# a3fa0d15dd83b910295d0b17f9d341e737eddcb8d9b8081758140584c710406e    1074
# Name: count, dtype: int64
#
# Column: post_id (Categorical)
# post_id
# 202cc020266f6ac23ec611b9f981df3748bd4a4abdf262a1f56e7abbc48c1dea    1
# 1b29933c5c00309e5cdf5e97c78ce0d387e76eb7f8c5d3db3561a7d2e0b56e1f    1
# 3e6a2773e1e16b7063fc74d11145c85dbaf2f8956bd54fe4412fb86752f03fd7    1
# 8c784531755c545757bc599cb3e0a406d07c02be0bc6e183049ff654bad2caa6    1
# 7fabce58a2152129dd1b94acc2d5d07fcbeb0715b47a1f3d993c2097aefe1b92    1
# Name: count, dtype: int64
#
# Column: Page Category (Categorical)
# Page Category
# PERSON                 9453
# ACTOR                  3304
# POLITICIAN             2595
# POLITICAL_CANDIDATE    1161
# ENTREPRENEUR             23
# Name: count, dtype: int64
#
# Column: Page Admin Top Country (Categorical)
# Page Admin Top Country
# US    16280
# Name: count, dtype: int64
#
# Column: Post Created (Categorical)
# Post Created
# 2024-10-30T20:57:00.000Z    2
# 2023-11-22 19:20:24 EST     2
# 2024-10-31T18:19:27.000Z    2
# 2024-10-31T12:17:11.000Z    2
# 2024-10-31T01:24:50.000Z    2
# Name: count, dtype: int64
#
# Finished in 0.21 seconds
#
# ============================================================
# Analyzing File: 2024_tw_posts_president_scored_anon.csv
# ============================================================
#
# --- Data Overview ---
# Shape: (27304, 47)
# Columns: ['id', 'url', 'source', 'retweetCount', 'replyCount', 'likeCount', 'quoteCount', 'viewCount', 'createdAt', 'lang', 'bookmarkCount', 'isReply', 'isRetweet', 'isQuote', 'isConversationControlled', 'quoteId', 'inReplyToId', 'month_year', 'illuminating_scored_message', 'election_integrity_Truth_illuminating', 'advocacy_msg_type_illuminating', 'issue_msg_type_illuminating', 'attack_msg_type_illuminating', 'image_msg_type_illuminating', 'cta_msg_type_illuminating', 'engagement_cta_subtype_illuminating', 'fundraising_cta_subtype_illuminating', 'voting_cta_subtype_illuminating', 'covid_topic_illuminating', 'economy_topic_illuminating', 'education_topic_illuminating', 'environment_topic_illuminating', 'foreign_policy_topic_illuminating', 'governance_topic_illuminating', 'health_topic_illuminating', 'immigration_topic_illuminating', 'lgbtq_issues_topic_illuminating', 'military_topic_illuminating', 'race_and_ethnicity_topic_illuminating', 'safety_topic_illuminating', 'social_and_cultural_topic_illuminating', 'technology_and_privacy_topic_illuminating', 'womens_issue_topic_illuminating', 'incivility_illuminating', 'scam_illuminating', 'freefair_illuminating', 'fraud_illuminating']
#
# --- Descriptive Statistics for First 5 Columns ---
#
# Column: id (Categorical)
# id
# 222a3046e0000ae632522ce79df362d67028311da9cfeb2aba4e9d495123e0ed    1
# cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a773b6cc2a65f03aa2d    1
# 0e3db0c35a290c6df3b737d15882846c108cc80a9b7e5ca64a0129d4e3cd3ad7    1
# 256905919085d2946d5d187abc6cbe81a8abe3384793b362fa6aa4144bf42776    1
# a461b32b31e72b222df7fdda0a8e68b0092e31deda33a8652eb443459546a4c4    1
# Name: count, dtype: int64
#
# Column: url (Categorical)
# url
# 9f6da3a01742bd3f2f82fb57392670c9a3c9b849821e3d9579abc9e696a6d119    1
# f70a206472e9deaf6e313297c1efb891729ced346a0aeb34e16935d78f74b937    1
# a1962f54943732a0dc006c33b4b6f5764c7085a1282a59439b891ee0eb59a0dc    1
# 4ddbbdb7f4d8ef62fccf3ed20c993bb665b8620fedb089e81b43c0c7bc0c613e    1
# c7e729c427e714baf06d88a2856a1be07d4ff52e1e633412ce15b0160e8f6c38    1
# Name: count, dtype: int64
#
# Column: source (Categorical)
# source
# Twitter Web App         14930
# Twitter for iPhone       8494
# Sprout Social            2933
# Twitter Media Studio      499
# Twitter for iPad          266
# Name: count, dtype: int64
#
# Column: retweetCount (Numeric)
# count     27304.000000
# mean       1322.055193
# std        3405.004240
# min           0.000000
# 25%          84.000000
# 50%         333.000000
# 75%        1071.000000
# max      144615.000000
# Name: retweetCount, dtype: float64
#
# Column: replyCount (Numeric)
# count     27304.000000
# mean       1063.785013
# std        3174.981654
# min           0.000000
# 25%          43.000000
# 50%         131.000000
# 75%         501.250000
# max      121270.000000
# Name: replyCount, dtype: float64
#
# Finished in 0.33 seconds
